# %%
import os
import glob
import mne
import numpy as np
from pathlib import Path

# ==============================
# CONFIGURATION
# ==============================

CONFIG = {
    "sampling_rate": 512,
    "bandpass": (0.5, 40),
    "epoch_window": (-0.2, 1.0),
    "baseline": (-0.2, 0),
    "reject_threshold": 100e-6,
    "ica_components": 20
}

RAW_DIR = Path("../../data/raw_data/ds006648-download")
FILTER_DIR = Path("../../data/intrmd_data/filtered")
FILTER_DIR.mkdir(exist_ok=True)
EPOCH_DIR = Path("../../data/intrmd_data/epochs")
EPOCH_DIR.mkdir(exist_ok=True)

# ==============================
# PREPROCESS FUNCTION
# ==============================

def preprocess_file(filepath):

    # subject = os.path.basename(filepath).split(".")[0]
    subject = next(p for p in Path(filepath).parts if p.startswith("sub-"))

    print(f"\nProcessing {subject}")

    # ------------------------------
    # 1 Load raw EEG
    # ------------------------------

    raw = mne.io.read_raw_eeglab(filepath, preload=True)

    # Set channel types for external electrodes
    raw.set_channel_types(
        {
            "EXG1": "eog",
            "EXG2": "eog",
            "EXG3": "eog",
            "EXG4": "eog",
            "EXG7": "ecg",
            "EXG8": "ecg",
        }
    )
    print("Loaded raw signal")

    # Visualize raw
    raw.plot(duration=10);
    # ------------------------------
    # 2 filter
    # ------------------------------
    # Notch filter
    raw.notch_filter(freqs=[50, 100], notch_widths=4)

    print("Notch filtering done")

    # Bandpass filter
    raw.filter(
        CONFIG["bandpass"][0],
        CONFIG["bandpass"][1]
    )

    print("Bandpass filtering done")

    # save filtered version
    filtered_path = os.path.join(
        FILTER_DIR, f"{subject}_filtered.fif"
    )
    raw.save(filtered_path, overwrite=True)
    
    # After filtering
    raw.plot_psd(fmax=60)

    # ------------------------------
    # 3 ICA artifact removal
    # ------------------------------

    print("Running ICA")

    ica = mne.preprocessing.ICA(
        n_components=CONFIG["ica_components"],
        random_state=97,
        max_iter="auto"
    )

    ica.fit(raw, decim=3)

    # automatic artifact detection
    eog_indices, _ = ica.find_bads_eog(raw)

    ica.exclude = eog_indices

    raw_clean = ica.apply(raw.copy())

    print(f"Removed ICA components: {ica.exclude}")

    # # ICA components
    # ica.plot_components();
    # Clean signal
    raw_clean.plot(duration=10);
    # ------------------------------
    # 4 Event detection
    # ------------------------------

    events, event_id = mne.events_from_annotations(raw_clean)

    print(f"Found {len(events)} events")
    print("Event mapping:", event_id)
    # Events
    mne.viz.plot_events(events);
    # ------------------------------
    # 5 Epoch extraction
    # ------------------------------

    epochs = mne.Epochs(
        raw_clean,
        events,
        event_id=event_id,
        tmin=CONFIG["epoch_window"][0],
        tmax=CONFIG["epoch_window"][1],
        baseline=CONFIG["baseline"],
        preload=True
    )
    print("Epoching done")
    # Epochs
    epochs.plot();
    # ------------------------------
    # 6 Reject bad epochs
    # ------------------------------

    epochs.drop_bad(
        reject=dict(eeg=CONFIG["reject_threshold"])
    )

    print(f"Remaining epochs: {len(epochs)}")
    # ERP
    epochs.average().plot()
    # ------------------------------
    # 7 Save epochs
    # ------------------------------

    save_path = os.path.join(
        EPOCH_DIR, f"{subject}_epo.fif"
    )

    epochs.save(save_path, overwrite=True)

    print("Saved cleaned epochs")


# ==============================
# SINGLE MODE
# ==============================

def run_batch():

    eeg_files = list(RAW_DIR.rglob("sub-*/eeg/*.set"))

    print(f"Found {len(eeg_files)} subjects")

    for file in eeg_files:
        preprocess_file(str(file))


# ==============================
# BATCH MODE
# ==============================


def run_single():

    eeg_files = list(RAW_DIR.rglob("sub-*/eeg/*.set"))

    if len(eeg_files) == 0:
        print("No EEG files found")
        return

    preprocess_file(str(eeg_files[0]))


# ==============================
# MAIN
# ==============================

if __name__ == "__main__":

    MODE = "single"
    # change to "batch" later

    if MODE == "single":
        run_single()

    if MODE == "batch":
        run_batch()
# Out:
# Processing sub-021
# /var/folders/hr/_514t0p560s6wx_xmwzg_vnm0000gn/T/ipykernel_6740/3939740759.py:41: RuntimeWarning: Not setting positions of 6 misc channels found in montage:
# ['EXG1', 'EXG2', 'EXG3', 'EXG4', 'EXG7', 'EXG8']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_eeglab(filepath, preload=True)
# /var/folders/hr/_514t0p560s6wx_xmwzg_vnm0000gn/T/ipykernel_6740/3939740759.py:44: RuntimeWarning: The unit for channel(s) EXG1, EXG2, EXG3, EXG4, EXG7, EXG8 has changed from NA to V.
#   raw.set_channel_types(
# Loaded raw signal
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Filtering raw data in 1 contiguous segment
# Setting up band-stop filter
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandstop filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower transition bandwidth: 0.50 Hz
# - Upper transition bandwidth: 0.50 Hz
# - Filter length: 3381 samples (6.604 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    1.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    3.3s finished
# Notch filtering done
# Filtering raw data in 1 contiguous segment
# Setting up band-pass filter from 0.5 - 40 Hz
#
# FIR filter parameters
# ---------------------
# Designing a one-pass, zero-phase, non-causal bandpass filter:
# - Windowed time-domain design (firwin) method
# - Hamming window with 0.0194 passband ripple and 53 dB stopband attenuation
# - Lower passband edge: 0.50
# - Lower transition bandwidth: 0.50 Hz (-6 dB cutoff frequency: 0.25 Hz)
# - Upper passband edge: 40.00 Hz
# - Upper transition bandwidth: 10.00 Hz (-6 dB cutoff frequency: 45.00 Hz)
# - Filter length: 3381 samples (6.604 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# Bandpass filtering done
# Overwriting existing file.
# Writing /Users/pramit/Documents/projects/neuro_astic/scripts/foo/../../data/intrmd_data/filtered/sub-021_filtered.fif
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:    2.3s finished
# /var/folders/hr/_514t0p560s6wx_xmwzg_vnm0000gn/T/ipykernel_6740/3939740759.py:78: RuntimeWarning: This filename (/Users/pramit/Documents/projects/neuro_astic/scripts/foo/../../data/intrmd_data/filtered/sub-021_filtered.fif) does not conform to MNE naming conventions. All raw files should end with raw.fif, raw_sss.fif, raw_tsss.fif, _meg.fif, _eeg.fif, _ieeg.fif, raw.fif.gz, raw_sss.fif.gz, raw_tsss.fif.gz, _meg.fif.gz, _eeg.fif.gz or _ieeg.fif.gz
#   raw.save(filtered_path, overwrite=True)
# Closing /Users/pramit/Documents/projects/neuro_astic/scripts/foo/../../data/intrmd_data/filtered/sub-021_filtered.fif
# [done]
# NOTE: plot_psd() is a legacy function. New code should use .compute_psd().plot().
# Effective window size : 4.000 (s)
# Plotting power spectral density (dB=True).
# Running ICA
# Fitting ICA to data using 64 channels (please be patient, this may take a while)
# /var/folders/hr/_514t0p560s6wx_xmwzg_vnm0000gn/T/ipykernel_6740/3939740759.py:81: RuntimeWarning: Channel locations not available. Disabling spatial colors.
#   raw.plot_psd(fmax=60)
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/mne/viz/utils.py:158: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   (fig or plt).show(**kwargs)
# Selecting by number: 20 components
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/scipy/linalg/_basic.py:1449: RuntimeWarning: divide by zero encountered in matmul
#   B = (u @ vh[:rank]).conj().T
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/scipy/linalg/_basic.py:1449: RuntimeWarning: overflow encountered in matmul
#   B = (u @ vh[:rank]).conj().T
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/scipy/linalg/_basic.py:1449: RuntimeWarning: invalid value encountered in matmul
#   B = (u @ vh[:rank]).conj().T
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/mne/utils/linalg.py:243: RuntimeWarning: divide by zero encountered in matmul
#   return (u @ vh[:rank]).conj().T
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/mne/utils/linalg.py:243: RuntimeWarning: overflow encountered in matmul
#   return (u @ vh[:rank]).conj().T
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/mne/utils/linalg.py:243: RuntimeWarning: invalid value encountered in matmul
#   return (u @ vh[:rank]).conj().T
# Fitting ICA took 9.7s.
# Using EOG channels: EXG1, EXG2, EXG3, EXG4
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5120 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5120 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5120 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5120 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5120 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5120 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# ... filtering ICA sources
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5120 samples (10.000 s)
#
# ... filtering target
# Setting up band-pass filter from 1 - 10 Hz
#
# FIR filter parameters
# ---------------------
# Designing a two-pass forward and reverse, zero-phase, non-causal bandpass filter:
# - Windowed frequency-domain design (firwin2) method
# - Hann window
# - Lower passband edge: 1.00
# - Lower transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 0.75 Hz)
# - Upper passband edge: 10.00 Hz
# - Upper transition bandwidth: 0.50 Hz (-12 dB cutoff frequency: 10.25 Hz)
# - Filter length: 5120 samples (10.000 s)
# [Parallel(n_jobs=1)]: Done  17 tasks      | elapsed:    0.7s
# [Parallel(n_jobs=1)]: Done  20 out of  20 | elapsed:    0.8s finished
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s finished
# Applying ICA to Raw instance
#     Transforming to ICA space (20 components)
#     Zeroing out 2 ICA components
#     Projecting back using 64 PCA components
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/mne/preprocessing/ica.py:2370: RuntimeWarning: divide by zero encountered in matmul
#   mixing = pca_components.T @ mixing
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/mne/preprocessing/ica.py:2370: RuntimeWarning: overflow encountered in matmul
#   mixing = pca_components.T @ mixing
# /Users/pramit/Documents/projects/neuro_astic/.ptanlys_venv/lib/python3.9/site-packages/mne/preprocessing/ica.py:2370: RuntimeWarning: invalid value encountered in matmul
#   mixing = pca_components.T @ mixing
# Removed ICA components: [np.int64(1), np.int64(4)]
# <MNELineFigure size 1000x350 with 1 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>
# Used Annotations descriptions: [np.str_('65281'), np.str_('65282'), np.str_('65283'), np.str_('65284'), np.str_('65285'), np.str_('65286'), np.str_('65287'), np.str_('65288')]
# Found 853 events
# Event mapping: {np.str_('65281'): 1, np.str_('65282'): 2, np.str_('65283'): 3, np.str_('65284'): 4, np.str_('65285'): 5, np.str_('65286'): 6, np.str_('65287'): 7, np.str_('65288'): 8}
# Not setting metadata
# 853 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# Using data from preloaded Raw for 853 events and 615 original time points ...
# 1 bad epochs dropped
# Epoching done
# <MNEBrowseFigure size 800x800 with 4 Axes>
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P5', 'Pz', 'CPz', 'Fp2', 'AF8', 'AFz', 'Fz', 'F8', 'FC6', 'FC4', 'FCz', 'Cz', 'C2', 'C4', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4']
#     Rejecting  epoch based on EEG : ['F1', 'F7', 'FC5', 'FC1', 'PO3', 'Fz', 'F2', 'F4', 'FC4', 'FC2', 'FCz', 'Cz', 'C2']
#     Rejecting  epoch based on EEG : ['PO8', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['F5']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['POz']
#     Rejecting  epoch based on EEG : ['PO3', 'POz', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['POz', 'O2']
#     Rejecting  epoch based on EEG : ['AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'PO7', 'PO3', 'O1', 'Oz', 'POz', 'Pz', 'CPz', 'Fp2', 'AF8', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['F5', 'F7', 'FC5', 'FC3', 'C3', 'C5', 'TP7', 'CP5', 'CP3', 'P5', 'Iz', 'FC6']
#     Rejecting  epoch based on EEG : ['T8', 'TP8', 'CP6']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF3', 'F1', 'F3', 'F5', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['FC4', 'C4', 'T8', 'TP8', 'CP6', 'CP4', 'P6', 'PO8']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F1', 'FC1', 'C1', 'AFz', 'Fz', 'F2', 'F8', 'FC2', 'FCz', 'Cz', 'C2']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['O2']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['F5', 'FC5']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['FT7']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['P1', 'P3', 'P5', 'P7', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'P4', 'P8', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['FC5', 'T7']
#     Rejecting  epoch based on EEG : ['FC3']
#     Rejecting  epoch based on EEG : ['Iz', 'Oz']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'CP6', 'CP4', 'CP2']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['PO7', 'O1']
#     Rejecting  epoch based on EEG : ['Iz', 'CP2']
#     Rejecting  epoch based on EEG : ['PO7', 'PO3', 'O1', 'Oz', 'POz', 'F4', 'FC4', 'C4', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['PO7', 'PO3', 'O1', 'POz', 'Pz']
#     Rejecting  epoch based on EEG : ['F5', 'F7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'TP7', 'CP5', 'CP3', 'CP1', 'FC4', 'Cz']
#     Rejecting  epoch based on EEG : ['PO7', 'PO3', 'O1', 'POz']
#     Rejecting  epoch based on EEG : ['F5', 'F7']
#     Rejecting  epoch based on EEG : ['F3', 'FT7', 'FC5', 'FC3', 'C3', 'T7', 'TP7', 'CP5', 'CP3', 'P5', 'PO7', 'PO3', 'O1', 'Oz', 'POz', 'FC4', 'C4', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['PO3', 'Oz', 'POz', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['PO7', 'PO8', 'O2']
#     Rejecting  epoch based on EEG : ['FC4', 'C4', 'TP8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Cz']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'FC3', 'C3', 'T7', 'TP7', 'CP5']
#     Rejecting  epoch based on EEG : ['T7', 'TP7', 'FC4', 'C4', 'T8', 'TP8', 'CP6', 'CP4']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'PO7', 'PO3', 'O1', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['TP7', 'CP5']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'FC3', 'C3', 'T7', 'TP7', 'CP5', 'CP3']
#     Rejecting  epoch based on EEG : ['PO7', 'PO3']
#     Rejecting  epoch based on EEG : ['T8', 'CP6']
#     Rejecting  epoch based on EEG : ['F1', 'FC1', 'AFz', 'Fz', 'F2', 'F4', 'FT8', 'FC4', 'FC2', 'FCz', 'C4', 'CP4']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['TP7', 'CP5']
#     Rejecting  epoch based on EEG : ['PO8', 'O2']
#     Rejecting  epoch based on EEG : ['AF7', 'F1', 'F3', 'F5', 'F7', 'FC5', 'FC3', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'AF8', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'C4', 'CP6', 'CP4', 'P6']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF3', 'F1', 'F3', 'FC3', 'FC1', 'C1', 'C3', 'CP3', 'P3', 'P5', 'P7', 'PO7', 'PO3', 'O1', 'Oz', 'POz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'TP8', 'CP4', 'P2']
#     Rejecting  epoch based on EEG : ['FC5', 'C3', 'T7', 'TP7', 'CP5']
#     Rejecting  epoch based on EEG : ['C3']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'T7', 'Fpz', 'Fp2', 'AF8', 'AFz', 'Fz', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'C4', 'C6', 'T8', 'CP6']
#     Rejecting  epoch based on EEG : ['Pz']
#     Rejecting  epoch based on EEG : ['F3', 'F5', 'F7', 'FC3', 'TP7', 'CP5']
#     Rejecting  epoch based on EEG : ['F1', 'FC1', 'C1', 'PO3', 'POz', 'CPz', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'FC2', 'FCz', 'Cz', 'C2', 'CP2', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['F7', 'TP7', 'CP5', 'F2', 'F4', 'F8', 'FC4', 'C4', 'TP8', 'CP6', 'CP4']
#     Rejecting  epoch based on EEG : ['AF7', 'F5', 'F7', 'F8']
#     Rejecting  epoch based on EEG : ['CP5']
#     Rejecting  epoch based on EEG : ['CP5', 'Fz', 'F2', 'F4', 'FC4']
#     Rejecting  epoch based on EEG : ['F1']
#     Rejecting  epoch based on EEG : ['O1', 'PO8', 'O2']
#     Rejecting  epoch based on EEG : ['PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['FCz']
#     Rejecting  epoch based on EEG : ['F5', 'CP5', 'FC4', 'C4', 'T8', 'CP6', 'CP4']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'F1', 'F3', 'F5', 'F7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'Fpz', 'Fp2', 'AF4', 'F8', 'FC6', 'Cz', 'C2', 'C6', 'TP8', 'CP6', 'CP4', 'CP2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['AF3', 'F1', 'F3', 'F5', 'F7', 'FC5', 'FC3', 'FC1', 'C3', 'T7', 'CP5', 'CP3', 'P1', 'P3', 'PO7', 'PO3', 'O1', 'Oz', 'POz', 'Pz', 'AFz', 'Fz', 'FC4', 'C4', 'T8', 'TP8', 'CP6', 'P2', 'P4', 'P8', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['F1', 'F3', 'F7', 'FC5', 'FC3', 'C3', 'CP5', 'F4', 'FC4', 'FC2']
#     Rejecting  epoch based on EEG : ['POz', 'Pz', 'CPz', 'FC4', 'C2', 'C4', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['PO8', 'O2']
#     Rejecting  epoch based on EEG : ['C4', 'PO8', 'O2']
#     Rejecting  epoch based on EEG : ['FC1', 'Pz', 'CPz', 'FCz', 'Cz', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['AF3', 'F1', 'F3', 'FC1', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'FC4', 'FC2', 'FCz', 'Cz']
#     Rejecting  epoch based on EEG : ['FC5', 'FC3', 'C3', 'T7', 'CP5', 'CP3']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF3', 'F1', 'F3', 'F5', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'CP3', 'CP1', 'P3', 'P5', 'PO7', 'PO3', 'O1', 'CPz', 'Fpz', 'Fp2', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'CP4', 'CP2', 'PO8', 'O2']
#     Rejecting  epoch based on EEG : ['F1', 'FC1', 'C1', 'CPz', 'Fz', 'FCz', 'Cz']
#     Rejecting  epoch based on EEG : ['F8', 'FC4', 'C4', 'T8', 'TP8', 'CP6', 'CP4', 'P6']
#     Rejecting  epoch based on EEG : ['CP6']
#     Rejecting  epoch based on EEG : ['AF7', 'F3', 'F5', 'FC5', 'FC3', 'C3', 'T7', 'CP5', 'CP3', 'F8', 'FC6', 'FC4', 'C6', 'TP8']
#     Rejecting  epoch based on EEG : ['FT7', 'FC5', 'FC3', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P5', 'Pz', 'CPz', 'F8', 'FC4', 'Cz', 'C2', 'C4', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2']
#     Rejecting  epoch based on EEG : ['FC5', 'FC3', 'C3', 'FC4', 'C4', 'CP6']
#     Rejecting  epoch based on EEG : ['FC4', 'PO8', 'O2']
#     Rejecting  epoch based on EEG : ['PO7', 'PO3', 'O1']
#     Rejecting  epoch based on EEG : ['PO3', 'POz', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['C3', 'CP3']
#     Rejecting  epoch based on EEG : ['FC5', 'FC3']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF3', 'F1', 'F3', 'FC3', 'FC1', 'AFz', 'Fz', 'F2']
#     Rejecting  epoch based on EEG : ['T7', 'TP7']
#     Rejecting  epoch based on EEG : ['PO3', 'POz', 'P2', 'P4', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['F8', 'CP6']
#     Rejecting  epoch based on EEG : ['AF7', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'P5', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'FC2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'P6']
#     Rejecting  epoch based on EEG : ['F5', 'AF8']
#     Rejecting  epoch based on EEG : ['F7']
#     Rejecting  epoch based on EEG : ['FC3', 'CP5']
#     Rejecting  epoch based on EEG : ['FC3', 'C3', 'T7', 'CP5', 'CP3']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'CP4', 'CP2', 'P2']
#     Rejecting  epoch based on EEG : ['POz', 'CPz', 'F2', 'P2']
#     Rejecting  epoch based on EEG : ['P2', 'P4', 'PO4']
#     Rejecting  epoch based on EEG : ['F1']
#     Rejecting  epoch based on EEG : ['AF3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'F2', 'F4', 'F8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['F3', 'FC5', 'FC3', 'C3', 'T7', 'CP5', 'CP3', 'F6', 'FC4', 'C4', 'CP6']
#     Rejecting  epoch based on EEG : ['F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C3', 'T7', 'TP7', 'CP5', 'CP3', 'P5', 'FC4', 'C4', 'CP6', 'CP4']
#     Rejecting  epoch based on EEG : ['PO7', 'PO3', 'O1']
#     Rejecting  epoch based on EEG : ['F7', 'FC5', 'FC3', 'C3', 'T7', 'TP7', 'CP5', 'F8', 'FC4', 'C4', 'T8', 'TP8', 'CP6', 'CP4', 'P6']
#     Rejecting  epoch based on EEG : ['FC5', 'FC3', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'F8']
#     Rejecting  epoch based on EEG : ['FC1', 'C1', 'CPz', 'FC2', 'FCz', 'Cz', 'C2']
#     Rejecting  epoch based on EEG : ['C3', 'C5']
#     Rejecting  epoch based on EEG : ['F1', 'F3', 'FC1', 'C1', 'CP1', 'Pz', 'CPz', 'AFz', 'Fz', 'F2', 'F4', 'FC2', 'FCz', 'Cz', 'C4', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['AF7', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'P3', 'P5', 'PO7', 'PO3', 'O1', 'Oz', 'POz', 'F4', 'F8', 'FT8', 'FC6', 'FC4', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'P6']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'P3', 'P5', 'P7', 'PO7', 'PO3', 'O1', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FC4', 'FC2', 'FCz', 'C2', 'C4', 'C6', 'CP6', 'CP4', 'CP2']
#     Rejecting  epoch based on EEG : ['FC4', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4']
#     Rejecting  epoch based on EEG : ['FC4', 'CP6']
#     Rejecting  epoch based on EEG : ['PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['PO3', 'O1', 'POz', 'Pz', 'Cz', 'CP4', 'CP2', 'P2', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['F7', 'T7', 'TP7', 'CP5']
#     Rejecting  epoch based on EEG : ['FT7', 'FC5', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'TP8']
#     Rejecting  epoch based on EEG : ['F5', 'FT7', 'FC5', 'FC3', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'P3', 'P5']
#     Rejecting  epoch based on EEG : ['PO8']
#     Rejecting  epoch based on EEG : ['PO8']
#     Rejecting  epoch based on EEG : ['F1', 'F3', 'FC1', 'C1', 'CPz', 'Fz', 'F2', 'F4', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'CP2']
#     Rejecting  epoch based on EEG : ['F1', 'F3', 'FC1', 'AF4', 'Fz', 'F2', 'F4', 'FC2', 'FCz']
#     Rejecting  epoch based on EEG : ['Iz', 'O2']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['C4', 'CP4']
#     Rejecting  epoch based on EEG : ['FCz', 'Cz']
#     Rejecting  epoch based on EEG : ['FC5', 'P9', 'CPz', 'Fz', 'F2', 'F4', 'FC6', 'FC2', 'FCz', 'Cz', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'PO8', 'O2']
#     Rejecting  epoch based on EEG : ['CP3', 'CP1', 'P1', 'P3', 'PO7', 'PO3', 'O1', 'POz', 'Pz', 'CPz', 'F2', 'F4', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'PO4']
#     Rejecting  epoch based on EEG : ['AFz', 'Fz', 'F2']
#     Rejecting  epoch based on EEG : ['F1']
#     Rejecting  epoch based on EEG : ['FC3', 'CP5']
#     Rejecting  epoch based on EEG : ['F1', 'FC1', 'AFz', 'Fz']
#     Rejecting  epoch based on EEG : ['F1', 'F3']
#     Rejecting  epoch based on EEG : ['AF3', 'F1', 'F3', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'PO3', 'POz', 'Pz', 'CPz', 'AF4', 'AFz', 'Fz', 'F2', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'PO4']
#     Rejecting  epoch based on EEG : ['CP6']
#     Rejecting  epoch based on EEG : ['T8', 'TP8']
#     Rejecting  epoch based on EEG : ['C1', 'C3', 'CP3', 'CP1', 'PO7', 'PO3', 'CPz', 'FC4', 'Cz', 'C2', 'C4', 'CP6', 'CP4']
#     Rejecting  epoch based on EEG : ['FC4', 'C4', 'CP6']
#     Rejecting  epoch based on EEG : ['P7', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'F8', 'PO8', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF3', 'F1', 'F3', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['FC5']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'P9', 'PO7', 'PO3', 'O1', 'Iz', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'P10', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['FC4', 'C4', 'T8']
#     Rejecting  epoch based on EEG : ['F8']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'P7', 'PO7', 'PO3', 'Oz', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6', 'P8', 'PO8', 'PO4', 'O2']
#     Rejecting  epoch based on EEG : ['PO8', 'O2']
#     Rejecting  epoch based on EEG : ['CP1', 'POz', 'Pz', 'CPz', 'Cz', 'C2', 'C4', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'P6']
#     Rejecting  epoch based on EEG : ['CP2', 'PO8', 'O2']
#     Rejecting  epoch based on EEG : ['TP8', 'CP6']
#     Rejecting  epoch based on EEG : ['Fp1', 'AF7', 'AF3', 'F1', 'F3', 'F5', 'FC5', 'FC3', 'FC1', 'C1', 'C3', 'C5', 'CP5', 'CP3', 'CP1', 'P1', 'P3', 'P5', 'PO3', 'POz', 'Pz', 'CPz', 'Fpz', 'Fp2', 'AF8', 'AF4', 'AFz', 'Fz', 'F2', 'F4', 'F6', 'F8', 'FC6', 'FC4', 'FC2', 'FCz', 'Cz', 'C2', 'C4', 'C6', 'CP6', 'CP4', 'CP2', 'P2', 'P4', 'PO4']
#     Rejecting  epoch based on EEG : ['C1', 'CP3', 'CP1', 'P1', 'P3', 'P9', 'PO7', 'PO3', 'O1', 'Oz', 'POz', 'Pz', 'CPz', 'FC2', 'FCz', 'Cz', 'CP2', 'P2', 'P4', 'PO4']
#     Rejecting  epoch based on EEG : ['AF7', 'F3', 'F5', 'F7', 'FT7', 'FC5', 'FC3', 'FC1', 'C3', 'C5', 'T7', 'TP7', 'CP5', 'CP3', 'P5', 'AF8', 'F6', 'F8', 'FT8', 'FC6', 'FC4', 'C4', 'C6', 'T8', 'TP8', 'CP6', 'CP4', 'P6', 'PO8']
#     Rejecting  epoch based on EEG : ['PO7', 'PO3', 'O1']
# 170 bad epochs dropped
# Remaining epochs: 682
# Overwriting existing file.
# Overwriting existing file.
# Saved cleaned epochs
