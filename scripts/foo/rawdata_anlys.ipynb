# %%
import mne

raw = mne.io.read_raw_eeglab(
    "../../data/raw_data/ds006648-download/sub-002/eeg/sub-002_task-readpoetry_eeg.set",
    preload=True
)
# print(raw.get_channel_types())
# print(mne.channel_indices_by_type(raw.info))
raw.set_channel_types(
    {
        "EXG1": "eog",
        "EXG2": "eog",
        "EXG3": "eog",
        "EXG4": "eog",
        "EXG7": "ecg",
        "EXG8": "ecg",
    }
)


# raw.plot(duration=1000, n_channels=10, scalings="auto")
# Out:
# /var/folders/hr/_514t0p560s6wx_xmwzg_vnm0000gn/T/ipykernel_8733/4224624511.py:3: RuntimeWarning: Not setting positions of 6 misc channels found in montage:
# ['EXG1', 'EXG2', 'EXG3', 'EXG4', 'EXG7', 'EXG8']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = mne.io.read_raw_eeglab(
# /var/folders/hr/_514t0p560s6wx_xmwzg_vnm0000gn/T/ipykernel_8733/4224624511.py:9: RuntimeWarning: The unit for channel(s) EXG1, EXG2, EXG3, EXG4, EXG7, EXG8 has changed from NA to V.
#   raw.set_channel_types(
# <RawEEGLAB | sub-002_task-readpoetry_eeg.set, 70 x 2975232 (5811.0 s), ~1.55 GB, data loaded>

# %%
# d=dict(
#     mag=1e-12,
#     grad=4e-11,
#     eeg=20e-6,
#     eog=150e-6,
#     ecg=5e-4,
#     emg=1e-3,
#     ref_meg=1e-12,
#     misc=1e-3,
#     stim=1,
#     resp=1,
#     chpi=1e-4,
#     whitened=1e2,
# )
# raw.plot(duration=10, scalings=d)
raw.plot(duration=10)
# Out:
# <MNEBrowseFigure size 800x800 with 4 Axes>
# <MNEBrowseFigure size 800x800 with 4 Axes>

# %%
mne.Epochs(raw)
# Out:
# Used Annotations descriptions: [np.str_('65281'), np.str_('65282'), np.str_('65283'), np.str_('65284'), np.str_('65285'), np.str_('65286'), np.str_('65287'), np.str_('65288')]
# Not setting metadata
# 853 matching events found
# Setting baseline interval to [-0.19921875, 0.0] s
# Applying baseline correction (mode: mean)
# 0 projection items activated
# <Epochs | 853 events (good & bad), -0.199 – 0.5 s (baseline -0.199 – 0 s), ~95 kB, data not loaded,
#  np.str_('65281'): 212
#  np.str_('65282'): 212
#  np.str_('65283'): 212
#  np.str_('65284'): 213
#  np.str_('65285'): 1
#  np.str_('65286'): 1
#  np.str_('65287'): 1
#  np.str_('65288'): 1>
